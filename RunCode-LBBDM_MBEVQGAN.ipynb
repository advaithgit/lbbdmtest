# %%
# !git clone https://github.com/RAGAV203/MSEVQQ.git
# Out:
# Cloning into 'MSEVQQ'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 192 (delta 37), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (192/192), 1.50 MiB | 11.49 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd /content/MSEVQQ/
# Out:
# /content/MSEVQQ

# %%
import gdown

url = 'https://drive.google.com/uc?id=1jUNENxz_ut01l65gGFLmUUuaQeWT7m_Z&export=download'
output = 'Brats.zip'
gdown.download(url, output, quiet=False)
# !unzip -q Brats.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1jUNENxz_ut01l65gGFLmUUuaQeWT7m_Z&export=download
# From (redirected): https://drive.google.com/uc?id=1jUNENxz_ut01l65gGFLmUUuaQeWT7m_Z&export=download&confirm=t&uuid=a1d2882f-9a70-4e59-8f10-4faf837ddf07
# To: /content/MSEVQQ/Brats.zip
# 100%|██████████| 45.8M/45.8M [00:00<00:00, 70.3MB/s]

# %%
import subprocess
import sys

def install_requirements():
    # List of packages with their versions
    requirements = [
        "absl-py==1.4.0",
        "aiohttp==3.8.4",
        "aiosignal==1.3.1",
        "albumentations==1.3.0",
        "antlr4-python3-runtime==4.9.3",
        "async-timeout==4.0.2",
        "attrs==22.2.0",
        "cachetools==5.3.0",
        "charset-normalizer==3.0.1",
        "einops==0.6.0",
        "filelock==3.9.0",
        "frozenlist==1.3.3",
        "fsspec==2023.1.0",
        "google-auth==2.16.2",
        "google-auth-oauthlib==0.4.6",
        "grpcio==1.51.3",
        "huggingface-hub==0.12.1",
        "idna==3.4",
        "imageio==2.26.0",
        "importlib-metadata==6.0.0",
        "joblib==1.2.0",
        "lazy-loader==0.1",
        "lightning-utilities==0.7.1",
        "lpips==0.1.4",
        "markdown==3.4.1",
        "markupsafe==2.1.2",
        "more-itertools==9.1.0",
        "multidict==6.0.4",
        "networkx==3.0",
        "numpy==1.24.2",
        "oauthlib==3.2.2",
        "omegaconf==2.3.0",
        "opencv-python==4.7.0.72",
        "opencv-python-headless==4.7.0.72",
        "packaging==23.0",
        "pillow==9.4.0",
        "protobuf==4.22.0",
        "pyasn1==0.4.8",
        "pyasn1-modules==0.2.8",
        "pytorch-lightning==1.9.3",
        "pywavelets==1.4.1",
        "pyyaml==6.0",
        "qudida==0.0.4",
        "regex==2022.10.31",
        "requests==2.28.2",
        "requests-oauthlib==1.3.1",
        "rsa==4.9",
        "scikit-image==0.20.0",
        "scikit-learn==1.2.1",
        "scipy==1.9.1",
        "six==1.16.0",
        "tensorboard==2.12.0",
        "tensorboard-data-server==0.7.0",
        "tensorboard-plugin-wit==1.8.1",
        "threadpoolctl==3.1.0",
        "tifffile==2023.2.27",
        "tokenizers==0.13.2",
        "torch==1.12.1+cu113",
        "torchaudio==0.12.1+cu113",
        "torchmetrics==0.11.1",
        "torchsummary==1.5.1",
        "torchvision==0.13.1+cu113",
        "tqdm==4.64.1",
        "transformers==4.26.1",
        "typing-extensions==4.5.0",
        "urllib3==1.26.14",
        "werkzeug==2.2.3",
        "yarl==1.8.2",
        "zipp==3.15.0"
    ]

    print("Starting installation of packages...")

    for package in requirements:
        try:
            #print(f"Installing {package}")
            subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        except subprocess.CalledProcessError as e:
            print(f"Failed to install {package}: {str(e)}")
        except Exception as e:
            print(f"An error occurred while installing {package}: {str(e)}")

    print("Installation complete!")

if __name__ == "__main__":
    install_requirements()
# Out:
# Starting installation of packages...
# Failed to install scipy==1.9.1: Command '['/usr/bin/python3', '-m', 'pip', 'install', 'scipy==1.9.1']' returned non-zero exit status 1.
# Failed to install torch==1.12.1+cu113: Command '['/usr/bin/python3', '-m', 'pip', 'install', 'torch==1.12.1+cu113']' returned non-zero exit status 1.
# Failed to install torchaudio==0.12.1+cu113: Command '['/usr/bin/python3', '-m', 'pip', 'install', 'torchaudio==0.12.1+cu113']' returned non-zero exit status 1.
# Failed to install torchvision==0.13.1+cu113: Command '['/usr/bin/python3', '-m', 'pip', 'install', 'torchvision==0.13.1+cu113']' returned non-zero exit status 1.
# Installation complete!

# %%
# !pip install accelerate==0.31.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 20.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.2.1
#     Uninstalling accelerate-1.2.1:
#       Successfully uninstalled accelerate-1.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-core 0.3.29 requires packaging<25,>=23.2, but you have packaging 23.0 which is incompatible.
# bigframes 1.31.0 requires fsspec>=2023.3.0, but you have fsspec 2023.1.0 which is incompatible.
# bigframes 1.31.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.2.1 which is incompatible.
# ...

# %%
import gdown

url = 'https://ommer-lab.com/files/latent-diffusion/vq-f4.zip'
output = 'vq-f4.zip'
gdown.download(url, output, quiet=False)
# !unzip -q vq-f4.zip
# Out:
# Downloading...
# From: https://ommer-lab.com/files/latent-diffusion/vq-f4.zip
# To: /content/MSEVQQ/vq-f4.zip
# 100%|██████████| 697M/697M [00:32<00:00, 21.7MB/s]

# %%
# !python3 main.py --config /content/MSEVQQ/configs/Template-LBBDM-f4.yaml --train --sample_at_start --save_top --gpu_ids 0
# Out:
# 2025-01-22 04:25:39.054696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-22 04:25:39.085704: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-22 04:25:39.095593: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 04:25:39.125007: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python3 main.py --config /content/MSEVQQ/configs/Template-LBBDM-f4.yaml --sample_to_eval --gpu_ids 0 --resume_model /content/MSE-BBDM/results/Brats/LBBDM-f4/checkpoint/last_model.pth

# %%
import matplotlib.pyplot as plt
import os

image_dir = '/content/MSEVQQ/results/Brats/LBBDM-f4/image/566/train_sample'

if os.path.exists(image_dir):
  for filename in os.listdir(image_dir):
    if filename == 'condition.png':
      image_path = os.path.join(image_dir, filename)
      img = plt.imread(image_path)
      plt.imshow(img)
      plt.title('Input Image')
      plt.show()
    elif filename == 'ground_truth.png':
      image_path = os.path.join(image_dir, filename)
      img = plt.imread(image_path)
      plt.imshow(img)
      plt.title('Ground Truth')
      plt.show()
    elif filename == 'skip_sample.png':
      image_path = os.path.join(image_dir, filename)
      img = plt.imread(image_path)
      plt.imshow(img)
      plt.title('Generated Output')
      plt.show()

# Note: Currently, Training only for 3 epochs for sampling

# %%
# prompt: given folder path zip it

import shutil
import os

def zip_folder(folder_path, output_filename):
    """Zips a folder and its contents.

    Args:
        folder_path: The path to the folder to zip.
        output_filename: The name of the output zip file.
    """
    try:
        shutil.make_archive(output_filename, 'zip', folder_path)
        print(f"Successfully created {output_filename}.zip")
    except FileNotFoundError:
        print(f"Error: Folder '{folder_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")


# Example usage: Replace with your desired folder path and output filename
folder_to_zip = "/content/MSE-BBDM/results/Brats/LBBDM-f4/sample_to_eval"  # Example folder path
output_zip_file = "Brats_samples"  # Output zip file name (without .zip extension)

zip_folder(folder_to_zip, output_zip_file)
